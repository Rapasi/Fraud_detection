# %%
import pandas as pd
from tensorflow import keras
import tensorflow as tf
from keras import metrics, models, layers
from keras.callbacks import EarlyStopping
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
data=pd.read_csv('Base.csv',encoding='utf8')

# %%
data.dropna(inplace=True)

# %%
data.dtypes
# Out:
# fraud_bool                            int64
# income                              float64
# name_email_similarity               float64
# prev_address_months_count             int64
# current_address_months_count          int64
# customer_age                          int64
# days_since_request                  float64
# intended_balcon_amount              float64
# payment_type                         object
# zip_count_4w                          int64
# velocity_6h                         float64
# velocity_24h                        float64
# velocity_4w                         float64
# bank_branch_count_8w                  int64
# date_of_birth_distinct_emails_4w      int64
# employment_status                    object
# credit_risk_score                     int64
# email_is_free                         int64
# housing_status                       object
# phone_home_valid                      int64
# phone_mobile_valid                    int64
# bank_months_count                     int64
# has_other_cards                       int64
# proposed_credit_limit               float64
# foreign_request                       int64
# source                               object
# session_length_in_minutes           float64
# device_os                            object
# keep_alive_session                    int64
# device_distinct_emails_8w             int64
# device_fraud_count                    int64
# month                                 int64
# dtype: object

# %%
data
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0                1     0.9               0.166828                         -1
# 1                1     0.9               0.296286                         -1
# 2                1     0.9               0.044985                         -1
# 3                1     0.9               0.159511                         -1
# 4                1     0.9               0.596414                         -1
# ...            ...     ...                    ...                        ...
# 999995           0     0.6               0.192631                         -1
# 999996           0     0.8               0.322989                        148
# 999997           0     0.8               0.879403                         -1
# 999998           0     0.9               0.762112                         -1
# 999999           0     0.2               0.697452                         -1
#
#         current_address_months_count  customer_age  days_since_request  \
# 0                                 88            50            0.020925
# 1                                144            50            0.005418
# 2                                132            40            3.108549
# 3                                 22            50            0.019079
# 4                                218            50            0.004441
# ...                              ...           ...                 ...
# 999995                           104            40            0.030592
# 999996                             9            50            1.628119
# 999997                            30            20            0.018563
# 999998                           189            20            0.015352
# 999999                           321            20            2.655916
#
#         intended_balcon_amount payment_type  zip_count_4w  ...  \
# 0                    -1.331345           AA           769  ...
# 1                    -0.816224           AB           366  ...
# 2                    -0.755728           AC           870  ...
# 3                    -1.205124           AB           810  ...
# 4                    -0.773276           AB           890  ...
# ...                        ...          ...           ...  ...
# 999995               -1.044454           AB           804  ...
# 999996               -1.409803           AC          3306  ...
# 999997               34.692760           AA          1522  ...
# 999998               94.661055           AA          1418  ...
# 999999                9.908499           AA           951  ...
#
#         has_other_cards  proposed_credit_limit  foreign_request    source  \
# 0                     0                  500.0                0  INTERNET
# 1                     0                 1500.0                0  INTERNET
# 2                     0                  200.0                0  INTERNET
# 3                     1                  200.0                0  INTERNET
# 4                     0                 1500.0                0  INTERNET
# ...                 ...                    ...              ...       ...
# 999995                0                  200.0                0  INTERNET
# 999996                0                  200.0                0  INTERNET
# 999997                0                  200.0                0  INTERNET
# 999998                0                  500.0                0  INTERNET
# 999999                0                  200.0                0  INTERNET
#
#         session_length_in_minutes  device_os  keep_alive_session  \
# 0                        3.888115    windows                   0
# 1                       31.798819    windows                   0
# 2                        4.728705      other                   0
# 3                        2.047904      linux                   0
# 4                        3.775225  macintosh                   1
# ...                           ...        ...                 ...
# 999995                   8.511502      linux                   1
# 999996                   8.967865    windows                   0
# 999997                   8.195531      other                   0
# 999998                   4.336064    windows                   1
# 999999                   6.717022      linux                   0
#
#         device_distinct_emails_8w device_fraud_count  month
# 0                               1                  0      7
# 1                               1                  0      7
# 2                               1                  0      7
# 3                               1                  0      7
# 4                               1                  0      7
# ...                           ...                ...    ...
# 999995                          1                  0      4
# 999996                          1                  0      4
# 999997                          1                  0      4
# 999998                          1                  0      4
# 999999                          1                  0      4
#
# [1000000 rows x 32 columns]

# %%
def encode_and_bind(original_dataframe, feature_to_encode):
    dummies = pd.get_dummies(original_dataframe[[feature_to_encode]])
    res = pd.concat([original_dataframe, dummies], axis=1)
    res = res.drop([feature_to_encode], axis=1) 
    return(res) 

features_to_encode = ['payment_type', 'employment_status', 'housing_status','source','device_os']
for feature in features_to_encode:
    data = encode_and_bind(data, feature)

# %%
data=data.sample(frac=1,random_state=468)

fraud=(data-data.min())/(data.max()-data.min())

fraud['fraud_bool']=data['fraud_bool']

# %%
fraud.fillna(0,inplace=True)

# %%
x, x_test = train_test_split(fraud,test_size=0.1,train_size=0.9,random_state=6544)
x_train, x_validation = train_test_split(x,test_size = 0.3,train_size =0.7,random_state=6544)

# %%
train_targets=x_train.pop('fraud_bool').astype('float64')
val_targets=x_validation.pop('fraud_bool').astype('float64')
test_targets=x_test.pop('fraud_bool').astype('float64')

# %%
METRICS= [
    metrics.FalseNegatives(name="fn"),
    metrics.FalsePositives(name="fp"),
    metrics.TrueNegatives(name="tn"),
    metrics.TruePositives(name="tp"),
    metrics.Precision(name="precision"),
    metrics.Recall(name="recall"),
]
class_weights = {0:1,
                 1:100}
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
model=models.Sequential()
model.add(layers.Dense(128, activation='relu',input_shape=(52,)))
model.add(layers.Dropout(0.15))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 128)               6784
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 15,105
# Trainable params: 15,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=METRICS)

# %%
history=model.fit(x=x_train,
                  y=train_targets,
                  epochs=20,
                  verbose=1,
                  batch_size=128,
                  callbacks=early_stopping,
                  class_weight=class_weights,
                  validation_data=(x_validation,val_targets))
# Out:
# Epoch 1/20
# 4922/4922 [==============================] - 11s 2ms/step - loss: 0.9754 - fn: 1390.0000 - fp: 143246.0000 - tn: 479818.0000 - tp: 5546.0000 - precision: 0.0373 - recall: 0.7996 - val_loss: 0.5711 - val_fn: 392.0000 - val_fp: 80143.0000 - val_tn: 186887.0000 - val_tp: 2578.0000 - val_precision: 0.0312 - val_recall: 0.8680
# Epoch 2/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.9479 - fn: 1292.0000 - fp: 141521.0000 - tn: 481543.0000 - tp: 5644.0000 - precision: 0.0384 - recall: 0.8137 - val_loss: 0.4874 - val_fn: 610.0000 - val_fp: 55827.0000 - val_tn: 211203.0000 - val_tp: 2360.0000 - val_precision: 0.0406 - val_recall: 0.7946
# Epoch 3/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.9394 - fn: 1278.0000 - fp: 140312.0000 - tn: 482752.0000 - tp: 5658.0000 - precision: 0.0388 - recall: 0.8157 - val_loss: 0.4239 - val_fn: 646.0000 - val_fp: 52685.0000 - val_tn: 214345.0000 - val_tp: 2324.0000 - val_precision: 0.0422 - val_recall: 0.7825
# Epoch 4/20
# 4922/4922 [==============================] - 9s 2ms/step - loss: 0.9302 - fn: 1243.0000 - fp: 137192.0000 - tn: 485872.0000 - tp: 5693.0000 - precision: 0.0398 - recall: 0.8208 - val_loss: 0.4340 - val_fn: 545.0000 - val_fp: 61410.0000 - val_tn: 205620.0000 - val_tp: 2425.0000 - val_precision: 0.0380 - val_recall: 0.8165
# Epoch 5/20
# 4922/4922 [==============================] - 9s 2ms/step - loss: 0.9222 - fn: 1242.0000 - fp: 138292.0000 - tn: 484772.0000 - tp: 5694.0000 - precision: 0.0395 - recall: 0.8209 - val_loss: 0.4009 - val_fn: 717.0000 - val_fp: 46188.0000 - val_tn: 220842.0000 - val_tp: 2253.0000 - val_precision: 0.0465 - val_recall: 0.7586
# Epoch 6/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.9168 - fn: 1216.0000 - fp: 136708.0000 - tn: 486356.0000 - tp: 5720.0000 - precision: 0.0402 - recall: 0.8247 - val_loss: 0.4318 - val_fn: 605.0000 - val_fp: 53949.0000 - val_tn: 213081.0000 - val_tp: 2365.0000 - val_precision: 0.0420 - val_recall: 0.7963
# Epoch 7/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.9060 - fn: 1187.0000 - fp: 136658.0000 - tn: 486406.0000 - tp: 5749.0000 - precision: 0.0404 - recall: 0.8289 - val_loss: 0.5988 - val_fn: 333.0000 - val_fp: 86170.0000 - val_tn: 180860.0000 - val_tp: 2637.0000 - val_precision: 0.0297 - val_recall: 0.8879
# Epoch 8/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.9016 - fn: 1133.0000 - fp: 137812.0000 - tn: 485252.0000 - tp: 5803.0000 - precision: 0.0404 - recall: 0.8366 - val_loss: 0.3831 - val_fn: 648.0000 - val_fp: 49424.0000 - val_tn: 217606.0000 - val_tp: 2322.0000 - val_precision: 0.0449 - val_recall: 0.7818
# Epoch 9/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.8943 - fn: 1172.0000 - fp: 136635.0000 - tn: 486429.0000 - tp: 5764.0000 - precision: 0.0405 - recall: 0.8310 - val_loss: 0.5087 - val_fn: 512.0000 - val_fp: 61410.0000 - val_tn: 205620.0000 - val_tp: 2458.0000 - val_precision: 0.0385 - val_recall: 0.8276
# Epoch 10/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.8884 - fn: 1137.0000 - fp: 137017.0000 - tn: 486047.0000 - tp: 5799.0000 - precision: 0.0406 - recall: 0.8361 - val_loss: 0.5009 - val_fn: 477.0000 - val_fp: 63402.0000 - val_tn: 203628.0000 - val_tp: 2493.0000 - val_precision: 0.0378 - val_recall: 0.8394
# Epoch 11/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.8854 - fn: 1171.0000 - fp: 134047.0000 - tn: 489017.0000 - tp: 5765.0000 - precision: 0.0412 - recall: 0.8312 - val_loss: 0.5190 - val_fn: 472.0000 - val_fp: 66080.0000 - val_tn: 200950.0000 - val_tp: 2498.0000 - val_precision: 0.0364 - val_recall: 0.8411
# Epoch 12/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.8783 - fn: 1106.0000 - fp: 134198.0000 - tn: 488866.0000 - tp: 5830.0000 - precision: 0.0416 - recall: 0.8405 - val_loss: 0.4914 - val_fn: 500.0000 - val_fp: 63054.0000 - val_tn: 203976.0000 - val_tp: 2470.0000 - val_precision: 0.0377 - val_recall: 0.8316
# Epoch 13/20
# 4922/4922 [==============================] - 10s 2ms/step - loss: 0.8730 - fn: 1118.0000 - fp: 133227.0000 - tn: 489837.0000 - tp: 5818.0000 - precision: 0.0418 - recall: 0.8388 - val_loss: 0.4521 - val_fn: 545.0000 - val_fp: 57040.0000 - val_tn: 209990.0000 - val_tp: 2425.0000 - val_precision: 0.0408 - val_recall: 0.8165

# %%
prediction = model.evaluate(x_test,test_targets,batch_size=32)
print(prediction)
# Out:
# 3125/3125 [==============================] - 2s 646us/step - loss: 0.5818 - fn: 132.0000 - fp: 28993.0000 - tn: 69884.0000 - tp: 991.0000 - precision: 0.0331 - recall: 0.8825
# [0.5817806124687195, 132.0, 28993.0, 69884.0, 991.0, 0.033050961792469025, 0.8824576735496521]

# %%
fraud.describe()
# Out:
#            fraud_bool          income  name_email_similarity  \
# count  1000000.000000  1000000.000000         1000000.000000
# mean         0.011029        0.578369               0.493694
# std          0.104438        0.362928               0.289125
# min          0.000000        0.000000               0.000000
# 25%          0.000000        0.250000               0.225215
# 50%          0.000000        0.625000               0.492152
# 75%          0.000000        0.875000               0.755567
# max          1.000000        1.000000               1.000000
#
#        prev_address_months_count  current_address_months_count  \
# count             1000000.000000                1000000.000000
# mean                    0.046142                      0.204168
# std                     0.114704                      0.206076
# min                     0.000000                      0.000000
# 25%                     0.000000                      0.046620
# 50%                     0.000000                      0.123543
# 75%                     0.033854                      0.305361
# max                     1.000000                      1.000000
#
#          customer_age  days_since_request  intended_balcon_amount  \
# count  1000000.000000      1000000.000000          1000000.000000
# mean         0.296113            0.013073                0.188283
# std          0.150322            0.068596                0.157495
# min          0.000000            0.000000                0.000000
# 25%          0.125000            0.000092                0.111677
# 50%          0.250000            0.000193                0.114408
# 75%          0.375000            0.000336                0.159663
# max          1.000000            1.000000                1.000000
#
#          zip_count_4w     velocity_6h  ...  housing_status_BE  \
# count  1000000.000000  1000000.000000  ...     1000000.000000
# mean         0.234616        0.345602  ...           0.169135
# std          0.150078        0.178216  ...           0.374871
# min          0.000000        0.000000  ...           0.000000
# 25%          0.133303        0.213605  ...           0.000000
# 50%          0.188386        0.325140  ...           0.000000
# 75%          0.290043        0.464956  ...           0.000000
# max          1.000000        1.000000  ...           1.000000
#
#        housing_status_BF  housing_status_BG  source_INTERNET  source_TELEAPP  \
# count     1000000.000000     1000000.000000   1000000.000000  1000000.000000
# mean            0.001669           0.000252         0.992952        0.007048
# std             0.040819           0.015873         0.083656        0.083656
# min             0.000000           0.000000         0.000000        0.000000
# 25%             0.000000           0.000000         1.000000        0.000000
# 50%             0.000000           0.000000         1.000000        0.000000
# 75%             0.000000           0.000000         1.000000        0.000000
# max             1.000000           1.000000         1.000000        1.000000
#
#        device_os_linux  device_os_macintosh  device_os_other  \
# count   1000000.000000       1000000.000000   1000000.000000
# mean          0.332712             0.053826         0.342728
# std           0.471185             0.225674         0.474622
# min           0.000000             0.000000         0.000000
# 25%           0.000000             0.000000         0.000000
# 50%           0.000000             0.000000         0.000000
# 75%           1.000000             0.000000         1.000000
# max           1.000000             1.000000         1.000000
#
#        device_os_windows   device_os_x11
# count     1000000.000000  1000000.000000
# mean            0.263506        0.007228
# std             0.440535        0.084710
# min             0.000000        0.000000
# 25%             0.000000        0.000000
# 50%             0.000000        0.000000
# 75%             1.000000        0.000000
# max             1.000000        1.000000
#
# [8 rows x 53 columns]
